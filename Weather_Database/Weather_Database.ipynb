# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
#Get the nearest city using the citipy module.

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
#Weather Map URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wdescription = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_wdescription})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | gondanglegi
# Processing Record 9 of Set 1 | laguna
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | fort william
# Processing Record 12 of Set 1 | parthenay
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | gizo
# Processing Record 15 of Set 1 | nsanje
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | sitka
# Processing Record 19 of Set 1 | charters towers
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | moerai
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | mount gambier
# Processing Record 26 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 1 | severo-kurilsk
# Processing Record 31 of Set 1 | rio gallegos
# Processing Record 32 of Set 1 | mandalgovi
# Processing Record 33 of Set 1 | narsaq
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | cayenne
# Processing Record 36 of Set 1 | poltavka
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | bouna
# Processing Record 43 of Set 1 | tighina
# Processing Record 44 of Set 1 | flinders
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | saint anthony
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | thinadhoo
# Processing Record 2 of Set 2 | cap malheureux
# Processing Record 3 of Set 2 | grindavik
# Processing Record 4 of Set 2 | valkeala
# Processing Record 5 of Set 2 | san patricio
# Processing Record 6 of Set 2 | jasper
# Processing Record 7 of Set 2 | deputatskiy
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | caluquembe
# Processing Record 10 of Set 2 | sokol
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | araceli
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | tibu
# Processing Record 15 of Set 2 | port blair
# Processing Record 16 of Set 2 | banda aceh
# Processing Record 17 of Set 2 | balao
# Processing Record 18 of Set 2 | madimba
# Processing Record 19 of Set 2 | cidreira
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | sao filipe
# Processing Record 22 of Set 2 | carnarvon
# Processing Record 23 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | tam ky
# Processing Record 27 of Set 2 | aneho
# Processing Record 28 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | hambantota
# Processing Record 31 of Set 2 | hamilton
# Processing Record 32 of Set 2 | horta
# Processing Record 33 of Set 2 | siderno
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | poum
# Processing Record 36 of Set 2 | haines junction
# Processing Record 37 of Set 2 | havelock
# Processing Record 38 of Set 2 | kirakira
# Processing Record 39 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | rincon
# Processing Record 42 of Set 2 | bambanglipuro
# Processing Record 43 of Set 2 | beloyarskiy
# Processing Record 44 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | calama
# Processing Record 47 of Set 2 | maymyo
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | alyangula
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | khorixas
# Processing Record 3 of Set 3 | atuona
# Processing Record 4 of Set 3 | sakaiminato
# Processing Record 5 of Set 3 | hilo
# Processing Record 6 of Set 3 | maarianhamina
# Processing Record 7 of Set 3 | coihaique
# Processing Record 8 of Set 3 | dali
# Processing Record 9 of Set 3 | margate
# Processing Record 10 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 3 | iquitos
# Processing Record 12 of Set 3 | lagoa
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | zyryanka
# Processing Record 15 of Set 3 | ostersund
# Processing Record 16 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 3 | la libertad
# Processing Record 18 of Set 3 | erzin
# Processing Record 19 of Set 3 | semnan
# Processing Record 20 of Set 3 | northam
# Processing Record 21 of Set 3 | bose
# Processing Record 22 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | san pedro de cajas
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 3 | taonan
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | east london
# Processing Record 30 of Set 3 | fortuna
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | oksfjord
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | puerto leguizamo
# Processing Record 35 of Set 3 | kaitangata
# Processing Record 36 of Set 3 | adrar
# Processing Record 37 of Set 3 | husavik
# Processing Record 38 of Set 3 | talnakh
# Processing Record 39 of Set 3 | penjamo
# Processing Record 40 of Set 3 | nikolskoye
# Processing Record 41 of Set 3 | maun
# Processing Record 42 of Set 3 | yuzhnyy
# Processing Record 43 of Set 3 | maturin
# Processing Record 44 of Set 3 | hernani
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | parauna
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | salinas
# Processing Record 50 of Set 3 | bandarbeyla
# Processing Record 1 of Set 4 | srednekolymsk
# Processing Record 2 of Set 4 | acari
# Processing Record 3 of Set 4 | saskylakh
# Processing Record 4 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | miri
# Processing Record 6 of Set 4 | gladstone
# Processing Record 7 of Set 4 | placido de castro
# Processing Record 8 of Set 4 | elati
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | chara
# Processing Record 11 of Set 4 | san quintin
# Processing Record 12 of Set 4 | lorengau
# Processing Record 13 of Set 4 | wagar
# Processing Record 14 of Set 4 | waipawa
# Processing Record 15 of Set 4 | yerbogachen
# Processing Record 16 of Set 4 | bandar-e lengeh
# Processing Record 17 of Set 4 | samarai
# Processing Record 18 of Set 4 | hasaki
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | constitucion
# Processing Record 21 of Set 4 | termiz
# Processing Record 22 of Set 4 | balkhash
# Processing Record 23 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 24 of Set 4 | grand gaube
# Processing Record 25 of Set 4 | tupik
# Processing Record 26 of Set 4 | vallenar
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 4 | cabo san lucas
# Processing Record 29 of Set 4 | mar del plata
# Processing Record 30 of Set 4 | camabatela
# Processing Record 31 of Set 4 | latung
# Processing Record 32 of Set 4 | abong mbang
# Processing Record 33 of Set 4 | noumea
# Processing Record 34 of Set 4 | fairlie
# Processing Record 35 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 4 | markala
# Processing Record 37 of Set 4 | biltine
# Processing Record 38 of Set 4 | vanimo
# Processing Record 39 of Set 4 | dunedin
# Processing Record 40 of Set 4 | yellowknife
# Processing Record 41 of Set 4 | caravelas
# Processing Record 42 of Set 4 | avera
# Processing Record 43 of Set 4 | lahaina
# Processing Record 44 of Set 4 | belaya gora
# Processing Record 45 of Set 4 | shimoda
# Processing Record 46 of Set 4 | pemba
# Processing Record 47 of Set 4 | hendrina
# Processing Record 48 of Set 4 | buala
# Processing Record 49 of Set 4 | iki-burul
# Processing Record 50 of Set 4 | leirvik
# Processing Record 1 of Set 5 | luderitz
# Processing Record 2 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 5 | tiarei
# Processing Record 4 of Set 5 | tambul
# City not found. Skipping...
# Processing Record 5 of Set 5 | storm lake
# Processing Record 6 of Set 5 | westport
# Processing Record 7 of Set 5 | port macquarie
# Processing Record 8 of Set 5 | gaogou
# Processing Record 9 of Set 5 | la carolina
# Processing Record 10 of Set 5 | unai
# Processing Record 11 of Set 5 | tampin
# Processing Record 12 of Set 5 | beyneu
# Processing Record 13 of Set 5 | isangel
# Processing Record 14 of Set 5 | ballina
# Processing Record 15 of Set 5 | udachnyy
# Processing Record 16 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 5 | pangnirtung
# Processing Record 18 of Set 5 | hoyanger
# Processing Record 19 of Set 5 | baykit
# Processing Record 20 of Set 5 | atambua
# Processing Record 21 of Set 5 | zheleznodorozhnyy
# Processing Record 22 of Set 5 | tovuz
# Processing Record 23 of Set 5 | snezhnogorsk
# Processing Record 24 of Set 5 | bandiagara
# Processing Record 25 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 5 | halifax
# Processing Record 27 of Set 5 | bosaso
# Processing Record 28 of Set 5 | faanui
# Processing Record 29 of Set 5 | huilong
# Processing Record 30 of Set 5 | bubaque
# Processing Record 31 of Set 5 | pampa
# Processing Record 32 of Set 5 | sankheda
# Processing Record 33 of Set 5 | nome
# Processing Record 34 of Set 5 | college
# Processing Record 35 of Set 5 | sisimiut
# Processing Record 36 of Set 5 | show low
# Processing Record 37 of Set 5 | tobe
# Processing Record 38 of Set 5 | kharp
# Processing Record 39 of Set 5 | lata
# Processing Record 40 of Set 5 | taoudenni
# Processing Record 41 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 5 | wagga wagga
# Processing Record 43 of Set 5 | sinnamary
# Processing Record 44 of Set 5 | bundaberg
# Processing Record 45 of Set 5 | tabas
# Processing Record 46 of Set 5 | hachinohe
# Processing Record 47 of Set 5 | paramonga
# Processing Record 48 of Set 5 | hervey bay
# Processing Record 49 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 5 | yaguajay
# Processing Record 1 of Set 6 | lurgan
# Processing Record 2 of Set 6 | touros
# Processing Record 3 of Set 6 | evensk
# Processing Record 4 of Set 6 | bathsheba
# Processing Record 5 of Set 6 | ternate
# Processing Record 6 of Set 6 | turkistan
# Processing Record 7 of Set 6 | bengkulu
# Processing Record 8 of Set 6 | morgantown
# Processing Record 9 of Set 6 | olafsvik
# Processing Record 10 of Set 6 | provideniya
# Processing Record 11 of Set 6 | karratha
# Processing Record 12 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 13 of Set 6 | saint-philippe
# Processing Record 14 of Set 6 | picos
# Processing Record 15 of Set 6 | amahai
# Processing Record 16 of Set 6 | requena
# Processing Record 17 of Set 6 | tiksi
# Processing Record 18 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 6 | yulara
# Processing Record 20 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 6 | marrakesh
# Processing Record 23 of Set 6 | chuy
# Processing Record 24 of Set 6 | yar-sale
# Processing Record 25 of Set 6 | mbuji-mayi
# Processing Record 26 of Set 6 | ilulissat
# Processing Record 27 of Set 6 | tall kayf
# Processing Record 28 of Set 6 | layou
# Processing Record 29 of Set 6 | muzhappilangad
# City not found. Skipping...
# Processing Record 30 of Set 6 | maceio
# Processing Record 31 of Set 6 | olga
# Processing Record 32 of Set 6 | ahipara
# Processing Record 33 of Set 6 | primorsko-akhtarsk
# Processing Record 34 of Set 6 | buin
# Processing Record 35 of Set 6 | kununurra
# Processing Record 36 of Set 6 | safranbolu
# Processing Record 37 of Set 6 | polunochnoye
# Processing Record 38 of Set 6 | atherton
# Processing Record 39 of Set 6 | cabedelo
# Processing Record 40 of Set 6 | clarence town
# Processing Record 41 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 6 | gulu
# Processing Record 43 of Set 6 | isiro
# Processing Record 44 of Set 6 | leningradskiy
# Processing Record 45 of Set 6 | epiniana
# Processing Record 46 of Set 6 | kruisfontein
# Processing Record 47 of Set 6 | sur
# Processing Record 48 of Set 6 | cubuk
# Processing Record 49 of Set 6 | praya
# Processing Record 50 of Set 6 | daxian
# City not found. Skipping...
# Processing Record 1 of Set 7 | contamana
# Processing Record 2 of Set 7 | puerto ayora
# Processing Record 3 of Set 7 | beaverlodge
# Processing Record 4 of Set 7 | soyo
# Processing Record 5 of Set 7 | zavodskoy
# Processing Record 6 of Set 7 | lahij
# Processing Record 7 of Set 7 | riyadh
# Processing Record 8 of Set 7 | nara
# Processing Record 9 of Set 7 | high level
# Processing Record 10 of Set 7 | bethel
# Processing Record 11 of Set 7 | el alto
# Processing Record 12 of Set 7 | asyut
# Processing Record 13 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 14 of Set 7 | yele
# Processing Record 15 of Set 7 | komsomolskiy
# Processing Record 16 of Set 7 | sao joao da barra
# Processing Record 17 of Set 7 | santa isabel do rio negro
# Processing Record 18 of Set 7 | iquique
# Processing Record 19 of Set 7 | lumeje
# Processing Record 20 of Set 7 | henties bay
# Processing Record 21 of Set 7 | komarikhinskiy
# Processing Record 22 of Set 7 | paamiut
# Processing Record 23 of Set 7 | saint pete beach
# Processing Record 24 of Set 7 | gamovo
# Processing Record 25 of Set 7 | labuhan
# Processing Record 26 of Set 7 | kushima
# Processing Record 27 of Set 7 | iqaluit
# Processing Record 28 of Set 7 | bela
# Processing Record 29 of Set 7 | mapiri
# Processing Record 30 of Set 7 | bogovarovo
# Processing Record 31 of Set 7 | winneba
# Processing Record 32 of Set 7 | pacific grove
# Processing Record 33 of Set 7 | sorland
# Processing Record 34 of Set 7 | bereda
# Processing Record 35 of Set 7 | dudinka
# Processing Record 36 of Set 7 | rio do sul
# Processing Record 37 of Set 7 | melsungen
# Processing Record 38 of Set 7 | port hardy
# Processing Record 39 of Set 7 | viedma
# Processing Record 40 of Set 7 | asau
# Processing Record 41 of Set 7 | abu samrah
# Processing Record 42 of Set 7 | pocosol
# Processing Record 43 of Set 7 | souillac
# Processing Record 44 of Set 7 | ponta delgada
# Processing Record 45 of Set 7 | ilhabela
# Processing Record 46 of Set 7 | orlik
# Processing Record 47 of Set 7 | kieta
# Processing Record 48 of Set 7 | constancia
# Processing Record 49 of Set 7 | almaznyy
# Processing Record 50 of Set 7 | bonavista
# Processing Record 1 of Set 8 | dingle
# Processing Record 2 of Set 8 | airai
# Processing Record 3 of Set 8 | lanxi
# Processing Record 4 of Set 8 | saint-joseph
# Processing Record 5 of Set 8 | taltal
# Processing Record 6 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 7 of Set 8 | ulaanbaatar
# Processing Record 8 of Set 8 | minab
# Processing Record 9 of Set 8 | norman wells
# Processing Record 10 of Set 8 | diego de almagro
# Processing Record 11 of Set 8 | hobyo
# Processing Record 12 of Set 8 | chom bung
# City not found. Skipping...
# Processing Record 13 of Set 8 | lazaro cardenas
# Processing Record 14 of Set 8 | mindelo
# Processing Record 15 of Set 8 | acapulco
# Processing Record 16 of Set 8 | galle
# Processing Record 17 of Set 8 | karaton
# Processing Record 18 of Set 8 | romodanovo
# Processing Record 19 of Set 8 | itarema
# Processing Record 20 of Set 8 | huarmey
# Processing Record 21 of Set 8 | osa
# Processing Record 22 of Set 8 | barranca
# Processing Record 23 of Set 8 | arys
# Processing Record 24 of Set 8 | wabrzezno
# Processing Record 25 of Set 8 | burriana
# Processing Record 26 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 8 | codrington
# Processing Record 28 of Set 8 | mogadishu
# Processing Record 29 of Set 8 | pouebo
# Processing Record 30 of Set 8 | conde
# Processing Record 31 of Set 8 | lilongwe
# Processing Record 32 of Set 8 | kalmunai
# Processing Record 33 of Set 8 | novo aripuana
# Processing Record 34 of Set 8 | moose factory
# Processing Record 35 of Set 8 | vostok
# Processing Record 36 of Set 8 | katobu
# Processing Record 37 of Set 8 | anqing
# Processing Record 38 of Set 8 | pontian kecil
# Processing Record 39 of Set 8 | shima
# Processing Record 40 of Set 8 | lompoc
# Processing Record 41 of Set 8 | horsham
# Processing Record 42 of Set 8 | skjervoy
# Processing Record 43 of Set 8 | bairiki
# Processing Record 44 of Set 8 | yumen
# Processing Record 45 of Set 8 | roald
# Processing Record 46 of Set 8 | kozhevnikovo
# Processing Record 47 of Set 8 | saint-augustin
# Processing Record 48 of Set 8 | notodden
# Processing Record 49 of Set 8 | vershino-darasunskiy
# Processing Record 50 of Set 8 | mersing
# Processing Record 1 of Set 9 | pisco
# Processing Record 2 of Set 9 | sechura
# Processing Record 3 of Set 9 | meulaboh
# Processing Record 4 of Set 9 | guerrero negro
# Processing Record 5 of Set 9 | pincher creek
# Processing Record 6 of Set 9 | teeli
# Processing Record 7 of Set 9 | ugoofaaru
# Processing Record 8 of Set 9 | dong hoi
# Processing Record 9 of Set 9 | taquarituba
# Processing Record 10 of Set 9 | xuddur
# Processing Record 11 of Set 9 | basoko
# Processing Record 12 of Set 9 | buluang
# Processing Record 13 of Set 9 | hofn
# Processing Record 14 of Set 9 | nago
# Processing Record 15 of Set 9 | chagoda
# Processing Record 16 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 9 | santa cruz
# Processing Record 18 of Set 9 | saint-georges
# Processing Record 19 of Set 9 | san policarpo
# Processing Record 20 of Set 9 | namtsy
# Processing Record 21 of Set 9 | tuatapere
# Processing Record 22 of Set 9 | cherskiy
# Processing Record 23 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 24 of Set 9 | adelaide
# Processing Record 25 of Set 9 | verkh-suetka
# Processing Record 26 of Set 9 | ban nahin
# Processing Record 27 of Set 9 | baoqing
# Processing Record 28 of Set 9 | angra
# City not found. Skipping...
# Processing Record 29 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 9 | orlovskiy
# Processing Record 31 of Set 9 | daru
# Processing Record 32 of Set 9 | arlit
# Processing Record 33 of Set 9 | genhe
# Processing Record 34 of Set 9 | gainesville
# Processing Record 35 of Set 9 | fairbanks
# Processing Record 36 of Set 9 | kilimatinde
# Processing Record 37 of Set 9 | izyum
# Processing Record 38 of Set 9 | mazyr
# Processing Record 39 of Set 9 | flagstaff
# Processing Record 40 of Set 9 | port lincoln
# Processing Record 41 of Set 9 | hualmay
# Processing Record 42 of Set 9 | ranong
# Processing Record 43 of Set 9 | washougal
# Processing Record 44 of Set 9 | ypsonas
# Processing Record 45 of Set 9 | chernyshevskiy
# Processing Record 46 of Set 9 | lasa
# Processing Record 47 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 48 of Set 9 | hay river
# Processing Record 49 of Set 9 | seoul
# Processing Record 50 of Set 9 | afsin
# Processing Record 1 of Set 10 | vao
# Processing Record 2 of Set 10 | ust-ishim
# Processing Record 3 of Set 10 | san jose
# Processing Record 4 of Set 10 | weligama
# Processing Record 5 of Set 10 | hami
# Processing Record 6 of Set 10 | novobirilyussy
# Processing Record 7 of Set 10 | bama
# Processing Record 8 of Set 10 | chengde
# Processing Record 9 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 10 | naze
# Processing Record 11 of Set 10 | moyale
# Processing Record 12 of Set 10 | ancud
# Processing Record 13 of Set 10 | vardo
# Processing Record 14 of Set 10 | yelizovo
# Processing Record 15 of Set 10 | mehamn
# Processing Record 16 of Set 10 | boali
# Processing Record 17 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 18 of Set 10 | foz
# Processing Record 19 of Set 10 | qinhuangdao
# Processing Record 20 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 10 | takoradi
# Processing Record 22 of Set 10 | saldanha
# Processing Record 23 of Set 10 | ampanihy
# Processing Record 24 of Set 10 | berlevag
# Processing Record 25 of Set 10 | mucurapo
# Processing Record 26 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 27 of Set 10 | panguna
# Processing Record 28 of Set 10 | kollumerland
# City not found. Skipping...
# Processing Record 29 of Set 10 | tovarkovskiy
# Processing Record 30 of Set 10 | ayan
# Processing Record 31 of Set 10 | mulchen
# Processing Record 32 of Set 10 | klaksvik
# Processing Record 33 of Set 10 | durban
# Processing Record 34 of Set 10 | ngaoundere
# Processing Record 35 of Set 10 | san cristobal
# Processing Record 36 of Set 10 | mazamari
# Processing Record 37 of Set 10 | ribas do rio pardo
# Processing Record 38 of Set 10 | uzhur
# Processing Record 39 of Set 10 | paita
# Processing Record 40 of Set 10 | talara
# Processing Record 41 of Set 10 | severnoye
# Processing Record 42 of Set 10 | dicabisagan
# Processing Record 43 of Set 10 | matara
# Processing Record 44 of Set 10 | beni suef
# Processing Record 45 of Set 10 | manokwari
# Processing Record 46 of Set 10 | anadyr
# Processing Record 47 of Set 10 | belyy yar
# Processing Record 48 of Set 10 | middlebury
# Processing Record 49 of Set 10 | swan river
# Processing Record 50 of Set 10 | indramayu
# Processing Record 1 of Set 11 | solwezi
# Processing Record 2 of Set 11 | oeiras
# Processing Record 3 of Set 11 | mahalapye
# Processing Record 4 of Set 11 | kamaishi
# Processing Record 5 of Set 11 | pitimbu
# Processing Record 6 of Set 11 | vlagtwedde
# Processing Record 7 of Set 11 | novovarshavka
# Processing Record 8 of Set 11 | lae
# Processing Record 9 of Set 11 | finschhafen
# Processing Record 10 of Set 11 | morondava
# Processing Record 11 of Set 11 | poya
# Processing Record 12 of Set 11 | salalah
# Processing Record 13 of Set 11 | guarapari
# Processing Record 14 of Set 11 | nortelandia
# Processing Record 15 of Set 11 | pokhara
# Processing Record 16 of Set 11 | san juan
# Processing Record 17 of Set 11 | irsha
# Processing Record 18 of Set 11 | kautokeino
# Processing Record 19 of Set 11 | beloha
# Processing Record 20 of Set 11 | springbok
# Processing Record 21 of Set 11 | san felipe
# Processing Record 22 of Set 11 | makakilo city
# Processing Record 23 of Set 11 | lavrentiya
# Processing Record 24 of Set 11 | soria
# Processing Record 25 of Set 11 | liusha
# Processing Record 26 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 11 | kashi
# Processing Record 28 of Set 11 | alvaraes
# Processing Record 29 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 11 | goderich
# Processing Record 31 of Set 11 | boffa
# Processing Record 32 of Set 11 | fuerte olimpo
# Processing Record 33 of Set 11 | saint-avold
# Processing Record 34 of Set 11 | ust-kulom
# Processing Record 35 of Set 11 | druzhba
# Processing Record 36 of Set 11 | booue
# Processing Record 37 of Set 11 | faya
# Processing Record 38 of Set 11 | gbarnga
# Processing Record 39 of Set 11 | awbari
# Processing Record 40 of Set 11 | nyurba
# Processing Record 41 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 11 | macae
# Processing Record 43 of Set 11 | winnipeg
# Processing Record 44 of Set 11 | naryan-mar
# Processing Record 45 of Set 11 | the valley
# Processing Record 46 of Set 11 | half moon bay
# Processing Record 47 of Set 11 | peddapalli
# Processing Record 48 of Set 11 | muli
# Processing Record 49 of Set 11 | sironko
# Processing Record 50 of Set 11 | santa rosa
# Processing Record 1 of Set 12 | muana
# Processing Record 2 of Set 12 | nahavand
# Processing Record 3 of Set 12 | charqueadas
# Processing Record 4 of Set 12 | khategaon
# Processing Record 5 of Set 12 | alihe
# Processing Record 6 of Set 12 | key west
# Processing Record 7 of Set 12 | kunming
# Processing Record 8 of Set 12 | makaha
# Processing Record 9 of Set 12 | ginir
# Processing Record 10 of Set 12 | barinas
# Processing Record 11 of Set 12 | mata
# Processing Record 12 of Set 12 | selma
# Processing Record 13 of Set 12 | pahalgam
# Processing Record 14 of Set 12 | cotonou
# Processing Record 15 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 12 | gillette
# Processing Record 17 of Set 12 | kyren
# Processing Record 18 of Set 12 | molteno
# Processing Record 19 of Set 12 | lewisville
# Processing Record 20 of Set 12 | tottori
# Processing Record 21 of Set 12 | yantal
# Processing Record 22 of Set 12 | dandong
# Processing Record 23 of Set 12 | zverinogolovskoye
# Processing Record 24 of Set 12 | kajaani
# Processing Record 25 of Set 12 | jahrom
# City not found. Skipping...
# Processing Record 26 of Set 12 | hovd
# Processing Record 27 of Set 12 | olinda
# Processing Record 28 of Set 12 | eydhafushi
# Processing Record 29 of Set 12 | iwanai
# Processing Record 30 of Set 12 | karlovac
# Processing Record 31 of Set 12 | novospasskoye
# Processing Record 32 of Set 12 | skelleftea
# Processing Record 33 of Set 12 | lufilufi
# Processing Record 34 of Set 12 | townsville
# Processing Record 35 of Set 12 | vila velha
# Processing Record 36 of Set 12 | pati
# Processing Record 37 of Set 12 | gorontalo
# Processing Record 38 of Set 12 | birjand
# Processing Record 39 of Set 12 | alekseyevsk
# Processing Record 40 of Set 12 | kopyevo
# City not found. Skipping...
# Processing Record 41 of Set 12 | kushiro
# Processing Record 42 of Set 12 | andrelandia
# Processing Record 43 of Set 12 | sola
# Processing Record 44 of Set 12 | nouadhibou
# Processing Record 45 of Set 12 | anchorage
# Processing Record 46 of Set 12 | makat
# Processing Record 47 of Set 12 | la rioja
# Processing Record 48 of Set 12 | diffa
# Processing Record 49 of Set 12 | nizhniy kuranakh
# Processing Record 50 of Set 12 | lookan
# Processing Record 1 of Set 13 | aste
# Processing Record 2 of Set 13 | khorramshahr
# Processing Record 3 of Set 13 | sarangani
# Processing Record 4 of Set 13 | tiznit
# Processing Record 5 of Set 13 | kutum
# Processing Record 6 of Set 13 | taunggyi
# Processing Record 7 of Set 13 | monrovia
# Processing Record 8 of Set 13 | saleilua
# City not found. Skipping...
# Processing Record 9 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 13 | bud
# Processing Record 11 of Set 13 | hudson bay
# Processing Record 12 of Set 13 | sciacca
# Processing Record 13 of Set 13 | mamlyutka
# Processing Record 14 of Set 13 | sozimskiy
# Processing Record 15 of Set 13 | oranjestad
# Processing Record 16 of Set 13 | bahia blanca
# Processing Record 17 of Set 13 | colac
# Processing Record 18 of Set 13 | troitsko-pechorsk
# Processing Record 19 of Set 13 | abrego
# Processing Record 20 of Set 13 | virginia beach
# Processing Record 21 of Set 13 | aksu
# Processing Record 22 of Set 13 | pryozerne
# Processing Record 23 of Set 13 | terney
# Processing Record 24 of Set 13 | chicama
# Processing Record 25 of Set 13 | saint-francois
# Processing Record 26 of Set 13 | puerto el triunfo
# Processing Record 27 of Set 13 | dumas
# Processing Record 28 of Set 13 | kerugoya
# Processing Record 29 of Set 13 | comodoro rivadavia
# Processing Record 30 of Set 13 | burica
# City not found. Skipping...
# Processing Record 31 of Set 13 | kofarnihon
# City not found. Skipping...
# Processing Record 32 of Set 13 | alvorada
# Processing Record 33 of Set 13 | mundi
# Processing Record 34 of Set 13 | berezovyy
# Processing Record 35 of Set 13 | macamic
# Processing Record 36 of Set 13 | narkanda
# Processing Record 37 of Set 13 | billings
# Processing Record 38 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 13 | sikeston
# Processing Record 40 of Set 13 | port hedland
# Processing Record 41 of Set 13 | katherine
# Processing Record 42 of Set 13 | kokstad
# Processing Record 43 of Set 13 | el tambo
# Processing Record 44 of Set 13 | pimenta bueno
# Processing Record 45 of Set 13 | saint george
# Processing Record 46 of Set 13 | siddapur
# Processing Record 47 of Set 13 | ullapool
# Processing Record 48 of Set 13 | timra
# Processing Record 49 of Set 13 | haapu
# City not found. Skipping...
# Processing Record 50 of Set 13 | wajima
# Processing Record 1 of Set 14 | fukue
# Processing Record 2 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 14 | aykhal
# Processing Record 4 of Set 14 | bogatyye saby
# Processing Record 5 of Set 14 | nishihara
# Processing Record 6 of Set 14 | makinsk
# Processing Record 7 of Set 14 | tabou
# Processing Record 8 of Set 14 | amberley
# Processing Record 9 of Set 14 | khani
# Processing Record 10 of Set 14 | simao
# Processing Record 11 of Set 14 | changji
# Processing Record 12 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 13 of Set 14 | zenzeli
# Processing Record 14 of Set 14 | marzuq
# Processing Record 15 of Set 14 | praxedis guerrero
# Processing Record 16 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 17 of Set 14 | naberera
# Processing Record 18 of Set 14 | sychevka
# Processing Record 19 of Set 14 | scarborough
# Processing Record 20 of Set 14 | sandane
# Processing Record 21 of Set 14 | eirunepe
# Processing Record 22 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 14 | aklavik
# Processing Record 24 of Set 14 | xining
# Processing Record 25 of Set 14 | tevriz
# Processing Record 26 of Set 14 | kita
# Processing Record 27 of Set 14 | price
# Processing Record 28 of Set 14 | lumphat
# Processing Record 29 of Set 14 | masterton
# Processing Record 30 of Set 14 | totkomlos
# Processing Record 31 of Set 14 | beringovskiy
# Processing Record 32 of Set 14 | coro
# Processing Record 33 of Set 14 | pavlovsk
# Processing Record 34 of Set 14 | trapani
# Processing Record 35 of Set 14 | kabin buri
# Processing Record 36 of Set 14 | bury saint edmunds
# City not found. Skipping...
# Processing Record 37 of Set 14 | dakar
# Processing Record 38 of Set 14 | champerico
# Processing Record 39 of Set 14 | luena
# Processing Record 40 of Set 14 | moletai
# Processing Record 41 of Set 14 | hastings
# Processing Record 42 of Set 14 | navashino
# Processing Record 43 of Set 14 | kirovskiy
# Processing Record 44 of Set 14 | novonikolayevskiy
# Processing Record 45 of Set 14 | williams lake
# Processing Record 46 of Set 14 | boyolangu
# Processing Record 47 of Set 14 | marmande
# Processing Record 48 of Set 14 | alice springs
# Processing Record 49 of Set 14 | beisfjord
# Processing Record 50 of Set 14 | ucluelet
# Processing Record 1 of Set 15 | nikolayevsk-na-amure
# Processing Record 2 of Set 15 | mahon
# Processing Record 3 of Set 15 | natal
# Processing Record 4 of Set 15 | kavaratti
# Processing Record 5 of Set 15 | tanabi
# Processing Record 6 of Set 15 | almasu mare
# Processing Record 7 of Set 15 | murakami
# Processing Record 8 of Set 15 | sibu
# Processing Record 9 of Set 15 | divnogorsk
# Processing Record 10 of Set 15 | hailar
# Processing Record 11 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 15 | kedrovyy
# Processing Record 13 of Set 15 | gamba
# Processing Record 14 of Set 15 | alofi
# Processing Record 15 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 16 of Set 15 | nagato
# Processing Record 17 of Set 15 | meadow lake
# Processing Record 18 of Set 15 | turtas
# Processing Record 19 of Set 15 | kenora
# Processing Record 20 of Set 15 | ambilobe
# Processing Record 21 of Set 15 | ajdabiya
# Processing Record 22 of Set 15 | qaqortoq
# Processing Record 23 of Set 15 | pindi gheb
# Processing Record 24 of Set 15 | cockburn town
# Processing Record 25 of Set 15 | strezhevoy
# Processing Record 26 of Set 15 | magistralnyy
# Processing Record 27 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 15 | iralaya
# Processing Record 29 of Set 15 | beihai
# Processing Record 30 of Set 15 | tilichiki
# Processing Record 31 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 15 | vadso
# Processing Record 33 of Set 15 | korla
# Processing Record 34 of Set 15 | lakes entrance
# Processing Record 35 of Set 15 | agaro
# Processing Record 36 of Set 15 | batamshinskiy
# Processing Record 37 of Set 15 | ulaangom
# Processing Record 38 of Set 15 | altus
# Processing Record 39 of Set 15 | san-pedro
# Processing Record 40 of Set 15 | qiongshan
# Processing Record 41 of Set 15 | nanortalik
# Processing Record 42 of Set 15 | vilhena
# Processing Record 43 of Set 15 | muroto
# Processing Record 44 of Set 15 | mackay
# Processing Record 45 of Set 15 | te anau
# Processing Record 46 of Set 15 | sept-iles
# Processing Record 47 of Set 15 | north bend
# Processing Record 48 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 49 of Set 15 | camacupa
# Processing Record 50 of Set 15 | nioro
# Processing Record 1 of Set 16 | zhigansk
# Processing Record 2 of Set 16 | juba
# Processing Record 3 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 16 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 16 | andenes
# Processing Record 6 of Set 16 | zyryanovsk
# Processing Record 7 of Set 16 | kaohsiung
# Processing Record 8 of Set 16 | luanda
# Processing Record 9 of Set 16 | nargana
# Processing Record 10 of Set 16 | daoukro
# Processing Record 11 of Set 16 | anloga
# Processing Record 12 of Set 16 | egvekinot
# Processing Record 13 of Set 16 | charleston
# Processing Record 14 of Set 16 | quatre cocos
# Processing Record 15 of Set 16 | cierna nad tisou
# Processing Record 16 of Set 16 | artyom
# Processing Record 17 of Set 16 | nieuw amsterdam
# Processing Record 18 of Set 16 | shepsi
# Processing Record 19 of Set 16 | toftir
# City not found. Skipping...
# Processing Record 20 of Set 16 | segamat
# Processing Record 21 of Set 16 | verkhnyaya sinyachikha
# Processing Record 22 of Set 16 | kamina
# Processing Record 23 of Set 16 | worthington
# Processing Record 24 of Set 16 | urazovka
# Processing Record 25 of Set 16 | beboto
# Processing Record 26 of Set 16 | saint-leu
# Processing Record 27 of Set 16 | ginda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hermanus      ZA -34.4187   19.2345     63.90        83         100
# 1   Georgetown      MY   5.4112  100.3354     79.90        86          20
# 2    Upernavik      GL  72.7868  -56.1549      3.47        96         100
# 3     Tasiilaq      GL  65.6145  -37.6368     33.96        95         100
# 4  New Norfolk      AU -42.7826  147.0587     63.66        68          11
# 5      Rikitea      PF -23.1203 -134.9692     77.70        79          46
# 6    Busselton      AU -33.6500  115.3333     47.08        73          43
# 7  Gondanglegi      ID  -7.7479  112.0132     75.76        85          23
# 8       Laguna      US  38.4210 -121.4238     55.99        91          90
# 9   Bredasdorp      ZA -34.5322   20.0403     61.29        82         100
#
#    Wind Speed Current Description
# 0        7.67     overcast clouds
# 1        1.01          few clouds
# 2        9.15     overcast clouds
# 3       27.02          light rain
# 4        1.52          few clouds
# 5       11.43          light rain
# 6        4.97    scattered clouds
# 7        6.93          few clouds
# 8        4.00       moderate rain
# 9        6.55     overcast clouds

# %%
# Export the DataFrame as a CSV file
city_data_df.to_csv("WeatherPy_Database.csv",index_label="City_ID")
